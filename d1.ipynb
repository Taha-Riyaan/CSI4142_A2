# %%
# import seaborn as sns
# import matplotlib.pyplot as plt
import kagglehub
import pandas as pd
import numpy as np

# %%
path = kagglehub.dataset_download(
    "nudratabbas/ai-worker-burnout-and-attrition-risk-dataset"
)
ogdf = pd.read_csv(f"{path}/ai_worker_burnout_attrition_2026.csv")
df = ogdf.copy()
# print("First 5 records:", df.head())

# %% [markdown]
# # Dataset 1 - AI Worker Burnout & Attrition Risk Dataset
# by John Lopes

# %% [markdown]
# ## Description

# %% [markdown]
# AI Worker Burnout & Attrition Risk Dataset by Nudrat Abbas
#
#
# ---
#
#
# purpose:
#
# "🤖 AI Worker Burnout & Attrition Risk — 2026
# As AI tools become deeply embedded in tech workflows, a new workplace
# crisis is emerging: AI-induced burnout. Tech workers are using more AI
# tools than ever — but at what cost to their mental health, job
# satisfaction, and career longevity?
#
# This dataset captures the intersection of AI tool adoption and
# employee wellbeing across 1,500 tech professionals globally in 2026."
#
#
# ---
#
#
# 1,500 rows 21 columns
#
#
#
# ---
#
#
# key features:
# *   Employee ID: Unique identifier for each employee
# *   Job Role: Role of employees
# *   Years Experience: years of experience of employees
# *   Education Level: highest level of education of employees
# *   Country: Country that employees are working from
# *   Industry: Industry that employees are working in
# *   Company Size: Company size that employees are working in
# *   Remote Work Type: Remote work status of employees (on-site, hybrid, fullly remote)
# *   Team Size: Team size that employees are working in
# *   Salary USD K: Salary of employees in USD measured in thousands
# *   Primary AI Tool: Most frequently used AI tool
# *   AI Tools Used Per Day: Number of distinct AI tools used daily
# *   Hours With AI Assistance Daily: Average hours per day spent working alongside AI tools
# *   AI Replaces My Tasks pct: % of employee's tasks they feel AI can already perform
# *   AI Adoption Stage: Company's AI maturity level: Experimenting → Integrating → Optimizing → AI-First
# *   Weekly AI Upskilling hrs: Hours per week spent learning new AI skills
# *   Productivity Score: Self-reported productivity score (Higher = more productive)
# *   Burnout Score: Composite burnout indicator (Higher = more burned out)
# *   Job Satisfaction 1-5: Job satisfaction rating on 1-5 scale (1 = very dissatisfied, 5 = very satisfied)
# *   Fear Of AI Replacement: Perceived threat of AI replacing their job (Low / Medium / High)
# *   Attrition Risk: Predicted likelihood of employees leaving their job within 12 months (Low / Medium / High)

# %% [markdown]
# ## Code

# %% [markdown]
# ### Data Type Errors

# %% [markdown]
# Data Type check:
#
# Checks that data entered is of the correct data type.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 2 - How you introduced such error
# Introduced error by setting fear of AI replacement to "massive" for 75 random employees
np.random.seed(51) # for reproducibility
randomEmployees = np.random.choice(1500, size=75, replace=False)
for i in range(75):
    df.loc[randomEmployees[i], "fear_of_ai_replacement"] = "massive"

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 3 - Checker code

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 4 - report of findings

# %% [markdown]
# ### Range Errors

# %% [markdown]
# Range check:
# Checks that data entered is within an acceptable range.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 2 - How you introduced such error
# Introduced error by setting fear of AI replacement to "massive" for 75 random employees
np.random.seed(86) # for reproducibility
randomEmployees = np.random.choice(1500, size=75, replace=False)
for i in range(75):
    df.loc[randomEmployees[i], "job_satisfaction_1_5"] = 6
print("Introduced errors at indices:", randomEmployees) #for testing purposes, to know where the errors are
# Out:
# Introduced errors at indices: [ 867  456  790  128  771 1032  773  315 1163  159 1334  832  308  966
#   696 1013  100  799 1315 1165  235  873  199  101  364  225  653  868
#   903  596  147  742  770  229   44 1230 1040  872  302  489  647  481
#   317 1364  930  119  597  803 1487  142 1283 1396 1403  432  478  907
#   870  778  170    1 1447  630 1188  257  863 1235  805 1049  960  732
#  1242 1239  340  133  548]

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 3 - Checker code
errorRows = [] # to store indices of rows with errors
# job_satisfaction_1_5 - assuming 1-5 is valid
rangeMask = ~df["job_satisfaction_1_5"].between(1, 5)
rangeIndicesSatisfaction = df[rangeMask].index.tolist()
errorRows.extend(rangeIndicesSatisfaction)
# print("Indices with job_satisfaction_1_5 out of range:", rangeIndicesSatisfaction)
# print("Number of errors found:", len(rangeIndicesSatisfaction))

# years_experience - assuming 0-70 years is valid
yearsExpMask = ~df["years_experience"].between(0, 70)
yearsExpIndices = df[yearsExpMask].index.tolist()
errorRows.extend(yearsExpIndices)

# burnout_score - assuming 0-100 scale
burnoutMask = ~df["burnout_score"].between(0, 100)
burnoutIndices = df[burnoutMask].index.tolist()
errorRows.extend(burnoutIndices)

# productivity_score - assuming 0-100 scale
productivityMask = ~df["productivity_score"].between(0, 100)
productivityIndices = df[productivityMask].index.tolist()
errorRows.extend(productivityIndices)

# weekly_ai_upskilling_hrs - assuming 0-168 hours
upSkillMask = ~df["weekly_ai_upskilling_hrs"].between(0, 168)
upSkillIndices = df[upSkillMask].index.tolist()
errorRows.extend(upSkillIndices)

# ai_replaces_my_tasks_pct - percentage, should be 0-100
replacesTasksMask = ~df["ai_replaces_my_tasks_pct"].between(0, 100)
replacesTasksIndices = df[replacesTasksMask].index.tolist()
errorRows.extend(replacesTasksIndices)

# hours_with_ai_assistance_daily - assuming 0-24 hours per day
hoursMask = ~df["hours_with_ai_assistance_daily"].between(0, 24)
hoursIndices = df[hoursMask].index.tolist()
errorRows.extend(hoursIndices)

# ai_tools_used_per_day - assuming 0-50 tools per day
toolsMask = ~df["ai_tools_used_per_day"].between(0, 50)
toolsIndices = df[toolsMask].index.tolist()
errorRows.extend(toolsIndices)

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 4 - report of findings
errorsFoundExample = rangeIndices[:3] # get first 3 errors found for demo purposes
print("Original values:")
print(ogdf["job_satisfaction_1_5"].loc[errorsFoundExample])
print("\n")
print("Modified values:")
print(df["job_satisfaction_1_5"].loc[errorsFoundExample])
# Out:
# Original values:
# 1      3.6
# 44     3.9
# 100    3.9
# Name: job_satisfaction_1_5, dtype: float64
#
#
# Modified values:
# 1      6.0
# 44     6.0
# 100    6.0
# Name: job_satisfaction_1_5, dtype: float64

# %% [markdown]
# ### Format Errors

# %% [markdown]
# Format check:
# Checks that data entered fits the defined format.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 2 - How you introduced such error
# Introduced error by setting fear of AI replacement to "massive" for 75 random employees
np.random.seed(28) # for reproducibility
randomEmployees = np.random.choice(1500, size=75, replace=False)
for i in range(75):
    df.loc[randomEmployees[i], "fear_of_ai_replacement"] = "massive"

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 3 - Checker code

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 4 - report of findings

# %% [markdown]
# ### Consistency Errors

# %% [markdown]
# Consistency check:
# Checks that data entered follows logical consistency.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 2 - How you introduced such error
# Introduced error by setting fear of AI replacement to "massive" for 75 random employees
np.random.seed(94) # for reproducibility
randomEmployees = np.random.choice(1500, size=75, replace=False)
for i in range(75):
    df.loc[randomEmployees[i], "fear_of_ai_replacement"] = "massive"

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 3 - Checker code

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 4 - report of findings

# %% [markdown]
# ### Uniqueness Errors

# %% [markdown]
# Uniqueness check:
# Checks that data entered that should be unique is.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 2 - How you introduced such error
# Introduced error by setting employee id to "EMP0075" for 75 random employees
np.random.seed(70) # for reproducibility
randomEmployees = np.random.choice(1500, size=75, replace=False)
for i in range(75):
    df.loc[randomEmployees[i], "employee_id"] = "EMP0075"
print("Introduced errors at indices:", randomEmployees) #for testing purposes, to know where the errors are
# Out:
# Introduced errors at indices: [1485  380  617  295  952  823  530  695 1323  939   23  518 1207  485
#  1277  184  646 1095  654  933  762 1050  833 1222  904  994  947  164
#   538  851 1274  635  487 1471 1443  668 1242  378  505 1375  493  765
#  1091 1111  586  674  537 1453  432 1216 1346  728  255  791  313  982
#   282  598  407   45  665  811  828  718  449  241  290  451 1256  299
#   169   24   35 1136   66]

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 3 - Checker code
duplicateMask = df.duplicated(subset=["employee_id"], keep=False)
duplicateIndices = df.index[duplicateMask].tolist()
# print("Duplicate employee_id found at indices:", duplicateIndices)

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 4 - report of findings
errorsFoundExample = duplicateIndices[:3] # get first 3 errors found for demo purposes
print("Original values:")
print(ogdf["employee_id"].loc[errorsFoundExample])
print("\n")
print("Modified values:")
print(df["employee_id"].loc[errorsFoundExample])
# Out:
# Original values:
# 23    EMP0024
# 24    EMP0025
# 35    EMP0036
# Name: employee_id, dtype: str
#
#
# Modified values:
# 23    EMP0075
# 24    EMP0075
# 35    EMP0075
# Name: employee_id, dtype: str

# %% [markdown]
# ### Presence Errors

# %% [markdown]
# Presence check:
# Checks that data entered in mandatory fields are not blank.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 2 - How you introduced such error
# Introduced error by setting job_role to None for 75 random employees
np.random.seed(37) # for reproducibility
randomEmployees = np.random.choice(1500, size=75, replace=False)
for i in range(75):
    df.loc[randomEmployees[i], "job_role"] = None
# print("Introduced errors at indices:", randomEmployees) #for testing purposes, to know where the errors are

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 3 - Checker code
# identify rows that are NaN or empty in any column
nullMask = df.isnull().any(axis=1)
emptyMask = (df == '').any(axis=1)

# rows where at least one column is null/empty
errorRows = df[nullMask | emptyMask]
errorIndices = errorRows.index.tolist()
# print("Indices of rows with errors:", errorIndices)
# print("problematic number of rows:", len(errorIndices))
# errorIndices, errorRows.head()

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 4 - report of findings
errorsFoundExample = errorIndices[:3] # get first 3 errors found for demo purposes
print("Original values:")
print(ogdf["job_role"].loc[errorsFoundExample])
print("\n")
print("Modified values:")
print(df["job_role"].loc[errorsFoundExample])
# Out:
# Original values:
# 16       Data Scientist
# 38       Data Scientist
# 79    AI Ethics Officer
# Name: job_role, dtype: str
#
#
# Modified values:
# 16    NaN
# 38    NaN
# 79    NaN
# Name: job_role, dtype: str

# %% [markdown]
# ### Length Errors

# %% [markdown]
# Length check:
# Checks that data entered has an approriate amount of characters.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 2 - How you introduced such error
# Introduced error by setting hours with ai assistance daily to have more than one decimal place for 75 random employees
np.random.seed(52) # for reproducibility
randomEmployees = np.random.choice(1500, size=75, replace=False)
for i in range(75):
    df.loc[randomEmployees[i], "hours_with_ai_assistance_daily"] = 5.5676
# print("Introduced errors at indices:", randomEmployees) #for testing purposes, to know where the errors are

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 3 - Checker code
# check that `hours_with_ai_assistance_daily` entries have only one decimal place

# convert to string so we can inspect the formatting
hoursInspect = df["hours_with_ai_assistance_daily"].astype(str)

# created mask to check if value is formated correctly with at most one decimal place 
hoursDecimalMask = hoursInspect.str.match(r'^\d+(\.\d)?$')

# indices of rows that violate the rule
hoursDecimalIndices = df[~hoursDecimalMask].index.tolist()

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 4 - report of findings
errorsFoundExample = hoursDecimalIndices[:3] # get first 3 errors found for demo purposes
print("Original values:")
print(ogdf["hours_with_ai_assistance_daily"].loc[errorsFoundExample])
print("\n")
print("Modified values:")
print(df["hours_with_ai_assistance_daily"].loc[errorsFoundExample])
# Out:
# Original values:
# 36    1.9
# 72    7.3
# 94    3.2
# Name: hours_with_ai_assistance_daily, dtype: float64
#
#
# Modified values:
# 36    5.5676
# 72    5.5676
# 94    5.5676
# Name: hours_with_ai_assistance_daily, dtype: float64

# %% [markdown]
# ### Look-up Errors

# %% [markdown]
# Look-Up check:
# Checks that data entered that has a limited set of values has a proper value using a table.

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 2 - How you introduced such error
# Introduced error by setting fear of AI replacement to "massive" for 75 random employees
np.random.seed(42) # for reproducibility
randomEmployees = np.random.choice(1500, size=75, replace=False)
for i in range(75):
    df.loc[randomEmployees[i], "fear_of_ai_replacement"] = "massive"
# print("Introduced errors at indices:", randomEmployees) #for testing purposes, to know where the errors are

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 3 - Checker code
# Check for invalid values in columns that specified acceptable values
errorRows = [] # to store rows with errors for reporting
adoptValues = ["Experimenting","Integrating", "Optimizing", "AI-First"] # values for ai_adoption_stage
adoptInvalid = df.loc[~df["ai_adoption_stage"].isin(adoptValues)].index.tolist() # get indices of rows where ai_adoption_stage is not in the valid values
# print("Invalid ai_adoption_stage values at indices:", adoptInvalid)
errorRows.extend(adoptInvalid)

replacementValues = ["Low", "Medium", "High"] # values for fear_of_ai_replacement
replacementInvalid = df.loc[~df["fear_of_ai_replacement"].isin(replacementValues)].index.tolist() # get indices of rows where fear_of_ai_replacement is not in the valid values
errorRows.extend(replacementInvalid)
# print("Invalid row indices:", replacementInvalid) # for testing purposes, to check that errors are caught
# print("Number of rows with errors found:", len(errorRows))

attritionValues = ["Low", "Medium", "High"] # values for attrition_risk
attritionInvalid = df.loc[~df["attrition_risk"].isin(attritionValues)].index.tolist() # get indices of rows where attrition_risk is not in the valid values
errorRows.extend(attritionInvalid)

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
#cell 4 - report of findings
errorsFoundExample = replacementInvalid[:3] # get first 3 errors found for demo purposes
print("Original values:")
print(ogdf["fear_of_ai_replacement"].loc[errorsFoundExample])
print("\n")
print("Modified values:")
print(df["fear_of_ai_replacement"].loc[errorsFoundExample])
# Out:
# Original values:
# 6       High
# 22    Medium
# 25    Medium
# Name: fear_of_ai_replacement, dtype: str
#
#
# Modified values:
# 6     massive
# 22    massive
# 25    massive
# Name: fear_of_ai_replacement, dtype: str

# %% [markdown]
# ## references
